# %% [markdown]
# # 6.1 WH Data Profile

# %% [markdown]
# ### This script contains the following:
# #### 1. Importing Libraries and Data
# #### 2. Data Cleaning
# #### 3. Data Wrangling
# #### 4. Data Merge
# #### 5. Exporting Data

# %% [markdown]
# ### 1. Importing Libraries and Data

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Define path

path = r'/Users/giadairene/Documents/CareerFoundry Data Analytics/Data Analytics Immersion/Achievement 6/World_Happiness_Analysis'

# %%
# Import data

df_2019 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'World Happiness Report 2019.csv'), index_col = False)

df_2020 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'World Happiness Report 2020.csv'), index_col = False)

df_2021 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'World Happiness Report 2021.csv'), index_col = False)

df_2022 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'World Happiness Report 2022.csv'), index_col = False)

df_2023 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'World Happiness Report 2023.csv'), index_col = False)

# %% [markdown]
# ### 2. Data Cleaning

# %% [markdown]
# #### Exploring Datasets:

# %%
# Check dataset shape

df_2019.shape
# Out:
# (156, 9)

# %%
df_2019.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df_2019.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
df_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
# Check dataset shape

df_2020.shape
# Out:
# (153, 20)

# %%
df_2020.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
df_2020.dtypes
# Out:
# Country name                                   object
# Regional indicator                             object
# Ladder score                                  float64
# Standard error of ladder score                float64
# upperwhisker                                  float64
# lowerwhisker                                  float64
# Logged GDP per capita                         float64
# Social support                                float64
# Healthy life expectancy                       float64
# Freedom to make life choices                  float64
# Generosity                                    float64
# Perceptions of corruption                     float64
# Ladder score in Dystopia                      float64
# Explained by: Log GDP per capita              float64
# Explained by: Social support                  float64
# Explained by: Healthy life expectancy         float64
# Explained by: Freedom to make life choices    float64
# ...

# %%
df_2020.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %%
# Check dataset shape

df_2021.shape
# Out:
# (149, 20)

# %%
df_2021.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
df_2021.dtypes
# Out:
# Country name                                   object
# Regional indicator                             object
# Ladder score                                  float64
# Standard error of ladder score                float64
# upperwhisker                                  float64
# lowerwhisker                                  float64
# Logged GDP per capita                         float64
# Social support                                float64
# Healthy life expectancy                       float64
# Freedom to make life choices                  float64
# Generosity                                    float64
# Perceptions of corruption                     float64
# Ladder score in Dystopia                      float64
# Explained by: Log GDP per capita              float64
# Explained by: Social support                  float64
# Explained by: Healthy life expectancy         float64
# Explained by: Freedom to make life choices    float64
# ...

# %%
df_2021.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
# Check dataset shape

df_2022.shape
# Out:
# (146, 12)

# %%
df_2022.columns
# Out:
# Index(['RANK', 'Country', 'Happiness score', 'Whisker-high', 'Whisker-low',
#        'Dystopia (1.83) + residual', 'Explained by: GDP per capita',
#        'Explained by: Social support', 'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption'],
#       dtype='object')

# %%
df_2022.dtypes
# Out:
# RANK                                            int64
# Country                                        object
# Happiness score                               float64
# Whisker-high                                  float64
# Whisker-low                                   float64
# Dystopia (1.83) + residual                    float64
# Explained by: GDP per capita                  float64
# Explained by: Social support                  float64
# Explained by: Healthy life expectancy         float64
# Explained by: Freedom to make life choices    float64
# Explained by: Generosity                      float64
# Explained by: Perceptions of corruption       float64
# dtype: object

# %%
df_2022.head()
# Out:
#    RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0     1      Finland            7.821         7.886        7.756
# 1     2      Denmark            7.636         7.710        7.563
# 2     3      Iceland            7.557         7.651        7.464
# 3     4  Switzerland            7.512         7.586        7.437
# 4     5  Netherlands            7.415         7.471        7.359
#
#    Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                       2.518                         1.892
# 1                       2.226                         1.953
# 2                       2.320                         1.936
# 3                       2.153                         2.026
# 4                       2.137                         1.945
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.258                                  0.775
# ...

# %%
# Check dataset shape

df_2023.shape
# Out:
# (137, 19)

# %%
df_2023.columns
# Out:
# Index(['Country name', 'Ladder score', 'Standard error of ladder score',
#        'upperwhisker', 'lowerwhisker', 'Logged GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
df_2023.dtypes
# Out:
# Country name                                   object
# Ladder score                                  float64
# Standard error of ladder score                float64
# upperwhisker                                  float64
# lowerwhisker                                  float64
# Logged GDP per capita                         float64
# Social support                                float64
# Healthy life expectancy                       float64
# Freedom to make life choices                  float64
# Generosity                                    float64
# Perceptions of corruption                     float64
# Ladder score in Dystopia                      float64
# Explained by: Log GDP per capita              float64
# Explained by: Social support                  float64
# Explained by: Healthy life expectancy         float64
# Explained by: Freedom to make life choices    float64
# Explained by: Generosity                      float64
# ...

# %%
df_2023.head()
# Out:
#   Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 0      Finland         7.804                           0.036         7.875
# 1      Denmark         7.586                           0.041         7.667
# 2      Iceland         7.530                           0.049         7.625
# 3       Israel         7.473                           0.032         7.535
# 4  Netherlands         7.403                           0.029         7.460
#
#    lowerwhisker  Logged GDP per capita  Social support  \
# 0         7.733                 10.792           0.969
# 1         7.506                 10.962           0.954
# 2         7.434                 10.896           0.983
# 3         7.411                 10.639           0.943
# 4         7.346                 10.942           0.930
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                   71.150                         0.961      -0.019
# ...

# %% [markdown]
# #### Missing Values Check:

# %%
# Check for missing values

df_2019.isnull().sum() # No missing values!
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
# Check for missing values

df_2020.isnull().sum() # No missing values!
# Out:
# Country name                                  0
# Regional indicator                            0
# Ladder score                                  0
# Standard error of ladder score                0
# upperwhisker                                  0
# lowerwhisker                                  0
# Logged GDP per capita                         0
# Social support                                0
# Healthy life expectancy                       0
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Ladder score in Dystopia                      0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           0
# ...

# %%
# Check for missing values

df_2021.isnull().sum() # No missing values!
# Out:
# Country name                                  0
# Regional indicator                            0
# Ladder score                                  0
# Standard error of ladder score                0
# upperwhisker                                  0
# lowerwhisker                                  0
# Logged GDP per capita                         0
# Social support                                0
# Healthy life expectancy                       0
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Ladder score in Dystopia                      0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           0
# ...

# %%
# Check for missing values

df_2022.isnull().sum() # No missing values!
# Out:
# RANK                                          0
# Country                                       0
# Happiness score                               0
# Whisker-high                                  0
# Whisker-low                                   0
# Dystopia (1.83) + residual                    0
# Explained by: GDP per capita                  0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# dtype: int64

# %%
# Check for missing values

df_2023.isnull().sum() # 3 missing values
# Out:
# Country name                                  0
# Ladder score                                  0
# Standard error of ladder score                0
# upperwhisker                                  0
# lowerwhisker                                  0
# Logged GDP per capita                         0
# Social support                                0
# Healthy life expectancy                       1
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Ladder score in Dystopia                      0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         1
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           1
# dtype: int64

# %% [markdown]
# #### Duplicates Check:

# %%
# Find duplicates

df_dups = df_2019[df_2019.duplicated()]

# %%
df_dups.shape # No duplicates!
# Out:
# (0, 9)

# %%
# Find duplicates

df_dups = df_2020[df_2020.duplicated()]

# %%
df_dups.shape # No duplicates!
# Out:
# (0, 20)

# %%
# Find duplicates

df_dups = df_2021[df_2021.duplicated()]

# %%
df_dups.shape # No duplicates!
# Out:
# (0, 20)

# %%
# Find duplicates

df_dups = df_2022[df_2022.duplicated()]

# %%
df_dups.shape # No duplicates!
# Out:
# (0, 12)

# %%
# Find duplicates

df_dups = df_2023[df_2023.duplicated()]

# %%
df_dups.shape # No duplicates!
# Out:
# (0, 19)

# %% [markdown]
# #### Mixed-Type Data:

# %%
for col in df_2019.columns.tolist():
      weird = (df_2019[[col]].map(type) != df_2019[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df_2019[weird]) > 0:
        print (col)
        
# No mixed-type columns either!

# %%
for col in df_2020.columns.tolist():
      weird = (df_2020[[col]].map(type) != df_2020[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df_2020[weird]) > 0:
        print (col)
        
# No mixed-type columns either!

# %%
for col in df_2021.columns.tolist():
      weird = (df_2021[[col]].map(type) != df_2021[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df_2021[weird]) > 0:
        print (col)
        
# No mixed-type columns either!

# %%
for col in df_2022.columns.tolist():
      weird = (df_2022[[col]].map(type) != df_2022[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df_2022[weird]) > 0:
        print (col)
        
# No mixed-type columns either!

# %%
for col in df_2023.columns.tolist():
      weird = (df_2023[[col]].map(type) != df_2023[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df_2023[weird]) > 0:
        print (col)
        
# No mixed-type columns either!

# %% [markdown]
# #### Descriptive Statistics:

# %%
df_2019.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %%
df_2020.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count     153.00000                      153.000000    153.000000
# mean        5.47324                        0.053538      5.578175
# std         1.11227                        0.018183      1.096823
# min         2.56690                        0.025902      2.628270
# 25%         4.72410                        0.040698      4.826248
# 50%         5.51500                        0.050606      5.607728
# 75%         6.22850                        0.060677      6.363886
# max         7.80870                        0.120590      7.869766
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    153.000000             153.000000      153.000000
# mean       5.368304               9.295706        0.808721
# std        1.128631               1.201588        0.121453
# min        2.505530               6.492642        0.319460
# 25%        4.603149               8.350645        0.737217
# ...

# %%
df_2021.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    149.000000                      149.000000    149.000000
# mean       5.532839                        0.058752      5.648007
# std        1.073924                        0.022001      1.054330
# min        2.523000                        0.026000      2.596000
# 25%        4.852000                        0.043000      4.991000
# 50%        5.534000                        0.054000      5.625000
# 75%        6.255000                        0.070000      6.344000
# max        7.842000                        0.173000      7.904000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.417631               9.432208        0.814745
# std        1.094879               1.158601        0.114889
# min        2.449000               6.635000        0.463000
# 25%        4.706000               8.541000        0.750000
# ...

# %%
df_2022.describe()
# Out:
#              RANK  Happiness score  Whisker-high  Whisker-low  \
# count  146.000000       146.000000    146.000000   146.000000
# mean    73.500000         5.553575      5.673589     5.433568
# std     42.290661         1.086843      1.065621     1.109380
# min      1.000000         2.404000      2.469000     2.339000
# 25%     37.250000         4.888750      5.006250     4.754750
# 50%     73.500000         5.568500      5.680000     5.453000
# 75%    109.750000         6.305000      6.448750     6.190000
# max    146.000000         7.821000      7.886000     7.756000
#
#        Dystopia (1.83) + residual  Explained by: GDP per capita  \
# count                  146.000000                    146.000000
# mean                     1.831808                      1.410445
# std                      0.534994                      0.421663
# min                      0.187000                      0.000000
# 25%                      1.555250                      1.095500
# ...

# %%
df_2023.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    137.000000                      137.000000    137.000000
# mean       5.539796                        0.064715      5.666526
# std        1.139929                        0.023031      1.117421
# min        1.859000                        0.029000      1.923000
# 25%        4.724000                        0.047000      4.980000
# 50%        5.684000                        0.060000      5.797000
# 75%        6.334000                        0.077000      6.441000
# max        7.804000                        0.147000      7.875000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    137.000000             137.000000      137.000000
# mean       5.412971               9.449796        0.799073
# std        1.163724               1.207302        0.129222
# min        1.795000               5.527000        0.341000
# 25%        4.496000               8.591000        0.722000
# ...

# %% [markdown]
# ### 3. Data Wrangling

# %% [markdown]
# #### Dropping Columns:

# %%
# Check columns

df_2020.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
# Drop unnecessary or not-in-common columns

df_2020 = df_2020.drop(columns=['Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
                                'Logged GDP per capita', 'Social support', 'Healthy life expectancy', 
                                'Freedom to make life choices', 'Generosity', 'Perceptions of corruption', 
                                'Ladder score in Dystopia', 'Dystopia + residual'])

# %%
# Check the output

df_2020.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                          1.285190                      1.499526
# 1                          1.326949                      1.503449
# 2                          1.390774                      1.472403
# 3                          1.326502                      1.547567
# 4                          1.424207                      1.495173
#
#    Explained by: Healthy life expectancy  \
# 0                               0.961271
# 1                               0.979333
# 2                               1.040533
# 3                               1.000843
# 4                               1.008072
#
# ...

# %%
# Check columns

df_2021.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
# Drop unnecessary or not-in-common columns

df_2021 = df_2021.drop(columns=['Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
                                'Logged GDP per capita', 'Social support', 'Healthy life expectancy', 
                                'Freedom to make life choices', 'Generosity', 'Perceptions of corruption', 
                                'Ladder score in Dystopia', 'Dystopia + residual'])

# %%
# Check the output

df_2021.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                             1.446                         1.106
# 1                             1.502                         1.108
# 2                             1.566                         1.079
# 3                             1.482                         1.172
# 4                             1.501                         1.079
#
#    Explained by: Healthy life expectancy  \
# 0                                  0.741
# 1                                  0.763
# 2                                  0.816
# 3                                  0.772
# 4                                  0.753
#
# ...

# %%
# Check columns

df_2022.columns
# Out:
# Index(['RANK', 'Country', 'Happiness score', 'Whisker-high', 'Whisker-low',
#        'Dystopia (1.83) + residual', 'Explained by: GDP per capita',
#        'Explained by: Social support', 'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption'],
#       dtype='object')

# %%
# Drop unnecessary or not-in-common columns

df_2022 = df_2022.drop(columns=['Whisker-high', 'Whisker-low', 'Dystopia (1.83) + residual'])

# %%
# Check the output

df_2022.head()
# Out:
#    RANK      Country  Happiness score  Explained by: GDP per capita  \
# 0     1      Finland            7.821                         1.892
# 1     2      Denmark            7.636                         1.953
# 2     3      Iceland            7.557                         1.936
# 3     4  Switzerland            7.512                         2.026
# 4     5  Netherlands            7.415                         1.945
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.258                                  0.775
# 1                         1.243                                  0.777
# 2                         1.320                                  0.803
# 3                         1.226                                  0.822
# 4                         1.206                                  0.787
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# ...

# %%
# Check columns

df_2023.columns
# Out:
# Index(['Country name', 'Ladder score', 'Standard error of ladder score',
#        'upperwhisker', 'lowerwhisker', 'Logged GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
# Drop unnecessary or not-in-common columns

df_2023 = df_2023.drop(columns=['Standard error of ladder score', 'upperwhisker', 'lowerwhisker', 
                                'Logged GDP per capita', 'Social support', 'Healthy life expectancy', 
                                'Freedom to make life choices', 'Generosity','Perceptions of corruption', 
                                'Ladder score in Dystopia', 'Dystopia + residual'])

# %%
# Check the output

df_2023.head()
# Out:
#   Country name  Ladder score  Explained by: Log GDP per capita  \
# 0      Finland         7.804                             1.888
# 1      Denmark         7.586                             1.949
# 2      Iceland         7.530                             1.926
# 3       Israel         7.473                             1.833
# 4  Netherlands         7.403                             1.942
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.585                                  0.535
# 1                         1.548                                  0.537
# 2                         1.620                                  0.559
# 3                         1.521                                  0.577
# 4                         1.488                                  0.545
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.772                     0.126
# ...

# %% [markdown]
# #### Renaming and Adding Columns:

# %%
# Check columns

df_2019.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
# Rename columns

df_2019.rename(columns = {'Overall rank' : 'Happiness_rank'}, inplace = True)

df_2019.rename(columns = {'Country or region' : 'Country'}, inplace = True)

df_2019.rename(columns = {'Score' : 'Happiness_score'}, inplace = True)

df_2019.rename(columns = {'GDP per capita' : 'GDP_capita'}, inplace = True)

df_2019.rename(columns = {'Social support' : 'Social_support'}, inplace = True)

df_2019.rename(columns = {'Healthy life expectancy' : 'Life_expectancy'}, inplace = True)

df_2019.rename(columns = {'Freedom to make life choices' : 'Freedom'}, inplace = True)

df_2019.rename(columns = {'Perceptions of corruption' : 'Corruption_perception'}, inplace = True)

# %%
# Assign column names in a specific order

df_2019 = df_2019[['Country', 'Happiness_rank', 'Happiness_score', 'GDP_capita', 'Social_support', 'Life_expectancy', 'Freedom', 'Generosity', 'Corruption_perception']]

# %%
# Add 'Year' column

df_2019.insert(1, 'Year', '2019')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/mb/xw76d1gs32108pqcbn2653hm0000gn/T/ipykernel_58851/1510596915.py in ?()
# ----> 1 df_test = df_2019.insert(1, 'Year', '2019')
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, loc, column, value, allow_duplicates)
#    4927                 "'self.flags.allows_duplicate_labels' is False."
#    4928             )
#    4929         if not allow_duplicates and column in self.columns:
#    4930             # Should this be a different kind of error??
# -> 4931             raise ValueError(f"cannot insert {column}, already exists")
#    4932         if not is_integer(loc):
#    4933             raise TypeError("loc must be int")
#    4934         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert Year, already exists

# %%
# Check output

df_2019
# Out:
#                       Country  Year  Happiness_rank  Happiness_score  \
# 0                     Finland  2019               1            7.769
# 1                     Denmark  2019               2            7.600
# 2                      Norway  2019               3            7.554
# 3                     Iceland  2019               4            7.494
# 4                 Netherlands  2019               5            7.488
# ..                        ...   ...             ...              ...
# 151                    Rwanda  2019             152            3.334
# 152                  Tanzania  2019             153            3.231
# 153               Afghanistan  2019             154            3.203
# 154  Central African Republic  2019             155            3.083
# 155               South Sudan  2019             156            2.853
#
#      GDP_capita  Social_support  Life_expectancy  Freedom  Generosity  \
# ...

# %%
# Check columns

df_2020.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption'],
#       dtype='object')

# %%
# Rename columns

df_2020.rename(columns = {'Regional indicator' : 'Region'}, inplace = True)

df_2020.rename(columns = {'Country name' : 'Country'}, inplace = True)

df_2020.rename(columns = {'Ladder score' : 'Happiness_score'}, inplace = True)

df_2020.rename(columns = {'Explained by: Log GDP per capita' : 'GDP_capita'}, inplace = True)

df_2020.rename(columns = {'Explained by: Social support' : 'Social_support'}, inplace = True)

df_2020.rename(columns = {'Explained by: Healthy life expectancy' : 'Life_expectancy'}, inplace = True)

df_2020.rename(columns = {'Explained by: Freedom to make life choices' : 'Freedom'}, inplace = True)

df_2020.rename(columns = {'Explained by: Generosity' : 'Generosity'}, inplace = True)

df_2020.rename(columns = {'Explained by: Perceptions of corruption' : 'Corruption_perception'}, inplace = True)

# %%
# Assign column names in a specific order

df_2020 = df_2020[['Country', 'Region', 'Happiness_score', 'GDP_capita', 'Social_support', 'Life_expectancy', 'Freedom', 'Generosity', 'Corruption_perception']]

# %%
# Add 'Year' column

df_2020.insert(2, 'Year', '2020')

# %%
# Check output

df_2020
# Out:
#                       Country              Region  Year  Happiness_score  \
# 0                     Finland      Western Europe  2020           7.8087
# 1                     Denmark      Western Europe  2020           7.6456
# 2                 Switzerland      Western Europe  2020           7.5599
# 3                     Iceland      Western Europe  2020           7.5045
# 4                      Norway      Western Europe  2020           7.4880
# ..                        ...                 ...   ...              ...
# 148  Central African Republic  Sub-Saharan Africa  2020           3.4759
# 149                    Rwanda  Sub-Saharan Africa  2020           3.3123
# 150                  Zimbabwe  Sub-Saharan Africa  2020           3.2992
# 151               South Sudan  Sub-Saharan Africa  2020           2.8166
# 152               Afghanistan          South Asia  2020           2.5669
#
#      GDP_capita  Social_support  Life_expectancy   Freedom  Generosity  \
# ...

# %%
# Check columns

df_2021.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption'],
#       dtype='object')

# %%
# Rename columns

df_2021.rename(columns = {'Regional indicator' : 'Region'}, inplace = True)

df_2021.rename(columns = {'Country name' : 'Country'}, inplace = True)

df_2021.rename(columns = {'Ladder score' : 'Happiness_score'}, inplace = True)

df_2021.rename(columns = {'Explained by: Log GDP per capita' : 'GDP_capita'}, inplace = True)

df_2021.rename(columns = {'Explained by: Social support' : 'Social_support'}, inplace = True)

df_2021.rename(columns = {'Explained by: Healthy life expectancy' : 'Life_expectancy'}, inplace = True)

df_2021.rename(columns = {'Explained by: Freedom to make life choices' : 'Freedom'}, inplace = True)

df_2021.rename(columns = {'Explained by: Generosity' : 'Generosity'}, inplace = True)

df_2021.rename(columns = {'Explained by: Perceptions of corruption' : 'Corruption_perception'}, inplace = True)

# %%
# Assign column names in a specific order

df_2021 = df_2021[['Country', 'Region', 'Happiness_score', 'GDP_capita', 'Social_support', 'Life_expectancy', 'Freedom', 'Generosity', 'Corruption_perception']]

# %%
# Add 'Year' column

df_2021.insert(2, 'Year', '2021')

# %%
# Check output

df_2021
# Out:
#          Country              Region  Year  Happiness_score  GDP_capita  \
# 0        Finland      Western Europe  2021            7.842       1.446
# 1        Denmark      Western Europe  2021            7.620       1.502
# 2    Switzerland      Western Europe  2021            7.571       1.566
# 3        Iceland      Western Europe  2021            7.554       1.482
# 4    Netherlands      Western Europe  2021            7.464       1.501
# ..           ...                 ...   ...              ...         ...
# 144      Lesotho  Sub-Saharan Africa  2021            3.512       0.451
# 145     Botswana  Sub-Saharan Africa  2021            3.467       1.099
# 146       Rwanda  Sub-Saharan Africa  2021            3.415       0.364
# 147     Zimbabwe  Sub-Saharan Africa  2021            3.145       0.457
# 148  Afghanistan          South Asia  2021            2.523       0.370
#
#      Social_support  Life_expectancy  Freedom  Generosity  \
# ...

# %%
# Check columns

df_2022.columns
# Out:
# Index(['RANK', 'Country', 'Happiness score', 'Explained by: GDP per capita',
#        'Explained by: Social support', 'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption'],
#       dtype='object')

# %%
# Rename columns

df_2022.rename(columns = {'RANK' : 'Happiness_rank'}, inplace = True)

df_2022.rename(columns = {'Country' : 'Country'}, inplace = True)

df_2022.rename(columns = {'Happiness score' : 'Happiness_score'}, inplace = True)

df_2022.rename(columns = {'Explained by: GDP per capita' : 'GDP_capita'}, inplace = True)

df_2022.rename(columns = {'Explained by: Social support' : 'Social_support'}, inplace = True)

df_2022.rename(columns = {'Explained by: Healthy life expectancy' : 'Life_expectancy'}, inplace = True)

df_2022.rename(columns = {'Explained by: Freedom to make life choices' : 'Freedom'}, inplace = True)

df_2022.rename(columns = {'Explained by: Generosity' : 'Generosity'}, inplace = True)

df_2022.rename(columns = {'Explained by: Perceptions of corruption' : 'Corruption_perception'}, inplace = True)

# %%
# Assign column names in a specific order

df_2022 = df_2022[['Country', 'Happiness_rank', 'Happiness_score', 'GDP_capita', 'Social_support', 'Life_expectancy', 'Freedom', 'Generosity', 'Corruption_perception']]

# %%
# Add 'Year' column

df_2022.insert(1, 'Year', '2022')

# %%
# Check output

df_2022
# Out:
#          Country  Year  Happiness_rank  Happiness_score  GDP_capita  \
# 0        Finland  2022               1            7.821       1.892
# 1        Denmark  2022               2            7.636       1.953
# 2        Iceland  2022               3            7.557       1.936
# 3    Switzerland  2022               4            7.512       2.026
# 4    Netherlands  2022               5            7.415       1.945
# ..           ...   ...             ...              ...         ...
# 141    Botswana*  2022             142            3.471       1.503
# 142      Rwanda*  2022             143            3.268       0.785
# 143     Zimbabwe  2022             144            2.995       0.947
# 144      Lebanon  2022             145            2.955       1.392
# 145  Afghanistan  2022             146            2.404       0.758
#
#      Social_support  Life_expectancy  Freedom  Generosity  \
# 0             1.258            0.775    0.736       0.109
# ...

# %%
# Check columns

df_2023.columns
# Out:
# Index(['Country name', 'Ladder score', 'Explained by: Log GDP per capita',
#        'Explained by: Social support', 'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption'],
#       dtype='object')

# %%
# Rename columns

df_2023.rename(columns = {'Country name' : 'Country'}, inplace = True)

df_2023.rename(columns = {'Ladder score' : 'Happiness_score'}, inplace = True)

df_2023.rename(columns = {'Explained by: Log GDP per capita' : 'GDP_capita'}, inplace = True)

df_2023.rename(columns = {'Explained by: Social support' : 'Social_support'}, inplace = True)

df_2023.rename(columns = {'Explained by: Healthy life expectancy' : 'Life_expectancy'}, inplace = True)

df_2023.rename(columns = {'Explained by: Freedom to make life choices' : 'Freedom'}, inplace = True)

df_2023.rename(columns = {'Explained by: Generosity' : 'Generosity'}, inplace = True)

df_2023.rename(columns = {'Explained by: Perceptions of corruption' : 'Corruption_perception'}, inplace = True)

# %%
# Assign column names in a specific order

df_2023 = df_2023[['Country', 'Happiness_score', 'GDP_capita', 'Social_support', 'Life_expectancy', 'Freedom', 'Generosity', 'Corruption_perception']]

# %%
# Add 'Year' column

df_2023.insert(1, 'Year', '2023')

# %%
# Check output

df_2023
# Out:
#               Country  Year  Happiness_score  GDP_capita  Social_support  \
# 0             Finland  2023            7.804       1.888           1.585
# 1             Denmark  2023            7.586       1.949           1.548
# 2             Iceland  2023            7.530       1.926           1.620
# 3              Israel  2023            7.473       1.833           1.521
# 4         Netherlands  2023            7.403       1.942           1.488
# ..                ...   ...              ...         ...             ...
# 132  Congo (Kinshasa)  2023            3.207       0.531           0.784
# 133          Zimbabwe  2023            3.204       0.758           0.881
# 134      Sierra Leone  2023            3.138       0.670           0.540
# 135           Lebanon  2023            2.392       1.417           0.476
# 136       Afghanistan  2023            1.859       0.645           0.000
#
#      Life_expectancy  Freedom  Generosity  Corruption_perception
# ...

# %% [markdown]
# ### 4. Data Merge

# %%
# Concatenate the dataframes along the rows

combined_df = pd.concat([df_2019, df_2020, df_2021, df_2022, df_2023])

# %%
# Check output

combined_df
# Out:
#               Country  Year  Happiness_rank  Happiness_score  GDP_capita  \
# 0             Finland  2019             1.0            7.769       1.340
# 1             Denmark  2019             2.0            7.600       1.383
# 2              Norway  2019             3.0            7.554       1.488
# 3             Iceland  2019             4.0            7.494       1.380
# 4         Netherlands  2019             5.0            7.488       1.396
# ..                ...   ...             ...              ...         ...
# 132  Congo (Kinshasa)  2023             NaN            3.207       0.531
# 133          Zimbabwe  2023             NaN            3.204       0.758
# 134      Sierra Leone  2023             NaN            3.138       0.670
# 135           Lebanon  2023             NaN            2.392       1.417
# 136       Afghanistan  2023             NaN            1.859       0.645
#
#      Social_support  Life_expectancy  Freedom  Generosity  \
# ...

# %%
# Assign column names in a specific order

combined_df = combined_df[['Country', 'Region', 'Year', 'Happiness_rank', 'Happiness_score', 'GDP_capita', 'Social_support', 'Life_expectancy', 'Freedom', 'Generosity', 'Corruption_perception']]

# %%
# Check output

combined_df
# Out:
#               Country Region  Year  Happiness_rank  Happiness_score  \
# 0             Finland    NaN  2019             1.0            7.769
# 1             Denmark    NaN  2019             2.0            7.600
# 2              Norway    NaN  2019             3.0            7.554
# 3             Iceland    NaN  2019             4.0            7.494
# 4         Netherlands    NaN  2019             5.0            7.488
# ..                ...    ...   ...             ...              ...
# 132  Congo (Kinshasa)    NaN  2023             NaN            3.207
# 133          Zimbabwe    NaN  2023             NaN            3.204
# 134      Sierra Leone    NaN  2023             NaN            3.138
# 135           Lebanon    NaN  2023             NaN            2.392
# 136       Afghanistan    NaN  2023             NaN            1.859
#
#      GDP_capita  Social_support  Life_expectancy  Freedom  Generosity  \
# 0         1.340           1.587            0.986    0.596       0.153
# ...

# %%
# Reset the index

combined_df.reset_index(drop=True, inplace=True)

# %%
combined_df
# Out:
#               Country Region  Year  Happiness_rank  Happiness_score  \
# 0             Finland    NaN  2019             1.0            7.769
# 1             Denmark    NaN  2019             2.0            7.600
# 2              Norway    NaN  2019             3.0            7.554
# 3             Iceland    NaN  2019             4.0            7.494
# 4         Netherlands    NaN  2019             5.0            7.488
# ..                ...    ...   ...             ...              ...
# 736  Congo (Kinshasa)    NaN  2023             NaN            3.207
# 737          Zimbabwe    NaN  2023             NaN            3.204
# 738      Sierra Leone    NaN  2023             NaN            3.138
# 739           Lebanon    NaN  2023             NaN            2.392
# 740       Afghanistan    NaN  2023             NaN            1.859
#
#      GDP_capita  Social_support  Life_expectancy  Freedom  Generosity  \
# 0         1.340           1.587            0.986    0.596       0.153
# ...

# %% [markdown]
# ### 5. Exporting data

# %%
# Export each wrangled dataset

df_2019.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_2019_wrangled.csv'))

df_2020.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_2020_wrangled.csv'))

df_2021.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_2021_wrangled.csv'))

df_2022.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_2022_wrangled.csv'))

df_2023.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_2023_wrangled.csv'))

# %%
# Export the combined dataset

combined_df.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Happiness_combined_all_years.csv'))
